# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\\python312.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.12_3.12.2032.0_x64__qbz5n2kfra8p0', 'c:\\Nihal\\Oxford\\Year 3\\B1\\Scientific Coding\\Practical\\b1-coding-practical-mt24\\.venv', '', 'c:\\Nihal\\Oxford\\Year 3\\B1\\Scientific Coding\\Practical\\b1-coding-practical-mt24\\.venv\\Lib\\site-packages', 'c:\\Nihal\\Oxford\\Year 3\\B1\\Scientific Coding\\Practical\\b1-coding-practical-mt24\\.venv\\Lib\\site-packages\\win32', 'c:\\Nihal\\Oxford\\Year 3\\B1\\Scientific Coding\\Practical\\b1-coding-practical-mt24\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Nihal\\Oxford\\Year 3\\B1\\Scientific Coding\\Practical\\b1-coding-practical-mt24\\.venv\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from dynamic import Submarine
from dynamic import ClosedLoop
from dynamic import Mission
from control import Controller

sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = Controller()
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
